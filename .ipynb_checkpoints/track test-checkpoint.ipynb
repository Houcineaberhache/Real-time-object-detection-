# %% [markdown]
# INSTALLING THE LIBRARIES
# ULTRALYTICS ---> YOLOV8
# SUPERVISION ---> BYTETRACK+COUNT

# %%
pip install ultralytics supervision
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------------------------- ------------- 0.8/1.2 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 5.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/824.0 kB ? eta -:--:--
#    ---------------------------------------- 824.0/824.0 kB 10.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/47.0 MB ? eta -:--:--
#    -- ------------------------------------- 3.4/47.0 MB 17.9 MB/s eta 0:00:03
#    --- ------------------------------------ 3.7/47.0 MB 13.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.6/47.0 MB 10.6 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.6/47.0 MB 10.6 MB/s eta 0:00:04
#    -------- ------------------------------- 10.0/47.0 MB 9.3 MB/s eta 0:00:04
#    ----------- ---------------------------- 13.4/47.0 MB 10.3 MB/s eta 0:00:04
# ...

# %%
from ultralytics import YOLO
import supervision as sv
from supervision.assets import download_assets, VideoAssets

# Supervision  assets download  video files
source_path=download_assets(VideoAssets.VEHICLES)
generator = sv.get_video_frames_generator(source_path)

# Load the pre-trained model for testing
model = YOLO("yolov8n.pt") 
model.fuse()
# Initialize ByteTrack (The version inside Supervision)
tracker = sv.ByteTrack()
#to prevent double ounting 
ids_already_logged = set()

START = sv.Point(0, 1500)
END = sv.Point(3840, 1500)

line_zone = sv.LineZone(start=START, end=END)
# Out:
# vehicles.mp4 asset download complete.
#
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
